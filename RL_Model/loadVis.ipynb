# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Load the CSV file into a DataFrame
df = pd.read_csv('C:\\Users\\saoudi\\Desktop\\Eya-PFE\\Data_RL\\Data_farms\\Robotic_Farm\\Landmann\\cooling_system_R_10min.csv', delimiter=';')
df.head()
# Out:
#           timestamp  Unnamed: 0.1  Unnamed: 0  \
# 0  15/08/2022 22:00     182608500   182608500
# 1  15/08/2022 22:10     182968500   182968500
# 2  15/08/2022 22:20     183328500   183328500
# 3  15/08/2022 22:30     183688500   183688500
# 4  15/08/2022 22:40     184048500   184048500
#
#                                            localtime      vrms     irms  \
# 0  16.08.2022 00:00:0016.08.2022 00:00:0116.08.20...  139464.1    208.9
# 1  16.08.2022 00:10:0016.08.2022 00:10:0116.08.20...  137394.5  24709.4
# 2  16.08.2022 00:20:0016.08.2022 00:20:0116.08.20...  138353.4   6614.3
# 3  16.08.2022 00:30:0016.08.2022 00:30:0116.08.20...  139077.6   7044.9
# 4  16.08.2022 00:40:0016.08.2022 00:40:0116.08.20...  138394.2   4881.3
#
#         watt       var         va     freq  ...    vrms_c  irms_c     watt_c  \
# 0    28039.9   16305.9    48056.7  29986.9  ...  139658.0    99.8    15815.8
# 1  5580274.9  335377.1  5610136.2  29996.6  ...  137571.0  8088.9  1834105.7
# ...

# %%
arr = np.arange(len(df['watt']))/144*24
arr.shape
# Out:
# (6486,)

# %%
fig = plt.figure(figsize=(18, 12))
plt.plot(arr[0:144],df['watt'][0:144])#,label='Lighting')
title=plt.title(" Cooling System Consumed Power")
title.set_size(22)
x_label =plt.xlabel('Time (Hour)')
x_label.set_size(22)
y_label =plt.ylabel('Power (W)')
y_label.set_size(22)

plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)
#plt.legend()

plt.show()
